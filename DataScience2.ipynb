# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"C:\Users\zabiz\Downloads\Data_Science\Tasks 2/Unemployment in India.csv")
dataset
# Out:
#              Region        Dated Frequency  Estimated_Unemployed_Rate_India  \
# 0    Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                             5.17
# ..              ...          ...       ...                              ...
# 749     West Bengal   29-02-2020   Monthly                             7.55
# 750     West Bengal   31-03-2020   Monthly                             6.67
# 751     West Bengal   30-04-2020   Monthly                            15.63
# 752     West Bengal   31-05-2020   Monthly                            15.22
# 753     West Bengal   30-06-2020   Monthly                             9.86
#
# ...

# %%
dataset.describe()
# Out:
#        Estimated_Unemployed_Rate_India  Estimated_Employed  \
# count                       740.000000        7.400000e+02
# mean                         11.787946        7.204460e+06
# std                          10.721298        8.087988e+06
# min                           0.000000        4.942000e+04
# 25%                           4.657500        1.190404e+06
# 50%                           8.350000        4.744178e+06
# 75%                          15.887500        1.127549e+07
# max                          76.740000        4.577751e+07
#
#        Estimated_Labour_particiption_Rate
# count                          740.000000
# mean                            42.630122
# std                              8.111094
# min                             13.330000
# 25%                             38.062500
# 50%                             41.160000
# 75%                             45.505000
# max                             72.570000

# %%
dataset.isnull().sum()
# Out:
# Region                                14
# Dated                                 14
# Frequency                             14
# Estimated_Unemployed_Rate_India       14
# Estimated_Employed                    14
# Estimated_Labour_particiption_Rate    14
# Area                                  14
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Region                                0
# Dated                                 0
# Frequency                             0
# Estimated_Unemployed_Rate_India       0
# Estimated_Employed                    0
# Estimated_Labour_particiption_Rate    0
# Area                                  0
# dtype: int64

# %%
dataset.head(5)
# Out:
#            Region        Dated Frequency  Estimated_Unemployed_Rate_India  \
# 0  Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1  Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2  Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3  Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4  Andhra Pradesh   30-09-2019   Monthly                             5.17
#
#    Estimated_Employed  Estimated_Labour_particiption_Rate   Area
# 0          11999139.0                               43.24  Rural
# 1          11755881.0                               42.05  Rural
# 2          12086707.0                               43.50  Rural
# 3          12285693.0                               43.97  Rural
# 4          12256762.0                               44.68  Rural

# %%
dataset.shape
# Out:
# (740, 7)

# %%
dataset.drop_duplicates()
# Out:
#              Region        Dated Frequency  Estimated_Unemployed_Rate_India  \
# 0    Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                             5.17
# ..              ...          ...       ...                              ...
# 749     West Bengal   29-02-2020   Monthly                             7.55
# 750     West Bengal   31-03-2020   Monthly                             6.67
# 751     West Bengal   30-04-2020   Monthly                            15.63
# 752     West Bengal   31-05-2020   Monthly                            15.22
# 753     West Bengal   30-06-2020   Monthly                             9.86
#
# ...

# %%
dataset.shape
# Out:
# (740, 7)

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Estimated_Unemployed_Rate_India",y="Region",data=dataset,color="g")
plt.title("Region vs Unemployed Rate")
plt.show()

# %%
plt.figure(figsize=(5,6))
sns.barplot(x="Area",y="Estimated_Unemployed_Rate_India",data=dataset,color="y")
plt.title("Area vs Unemployed Rate")
plt.show()

# %%
plt.figure(figsize=(5,6))
sns.barplot(x="Estimated_Employed",y="Region",data=dataset,color="y")
plt.title("Estimated_Employed vs Region")
plt.show()

# %%
sns.violinplot(x="Area",y="Estimated_Unemployed_Rate_India",data=dataset)
plt.show()

# %%
sns.scatterplot(x="Estimated_Labour_particiption_Rate",y="Estimated_Unemployed_Rate_India",data=dataset)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=dataset, x='Dated', y='Estimated_Unemployed_Rate_India')
plt.title('Unemployment Rate Over Time')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=dataset, x='Region', y='Estimated_Unemployed_Rate_India')
plt.title('Unemployment Rate by Region')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=dataset, x='Region', y='Estimated_Unemployed_Rate_India')
plt.title('Unemployment Rate by Region')
plt.xticks(rotation=90)
plt.show()

# %%
# Ensure 'Date' is in datetime format
dataset['Dated'] = pd.to_datetime(dataset["Dated"])

# Define time periods
pre_covid = dataset[dataset['Dated'] < '2020-03-01']
during_covid = dataset[(dataset['Dated'] >= '2020-03-01') & (dataset['Dated'] <= '2021-03-01')]

# Compare averages
print("Pre-Covid Unemployment Rate:", pre_covid['Estimated_Unemployed_Rate_India'].mean())
print("During-Covid Unemployment Rate:", during_covid['Estimated_Labour_particiption_Rate'].mean())
# Out:
# Pre-Covid Unemployment Rate: 9.509533582089553
# During-Covid Unemployment Rate: 39.33004901960784

# %%
import seaborn as sns

dataset['Period'] = dataset['Dated'].apply(lambda d: 'Pre-Covid' if d < pd.to_datetime('2020-03-01') else 'During-Covid')
sns.boxplot(data=dataset, x='Period', y='Estimated_Unemployed_Rate_India')
plt.title("Unemployment Rate Before vs During Covid")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import seaborn as sns
#       3 dataset['Period'] = dataset['Dated'].apply(lambda d: 'Pre-Covid' if d < pd.to_datetime('2020-03-01') else 'During-Covid')
#       4 sns.boxplot(data=dataset, x='Period', y='Estimated_Unemployed_Rate_India')
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# ## 📌 Insights & Policy Recommendations
# ### Unemployment rates spiked during the Covid-19 pandemic, highlighting the need for stronger employment support systems during national emergencies.
#
# ### Seasonal trends show higher unemployment in certain months — policymakers could plan seasonal job programs.
#
# ## Focus should be placed on economic recovery plans during pandemics and reskilling the workforce.
